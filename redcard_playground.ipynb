# %% [markdown]
# Project: red_card
# =====
#
# ## Crowdstorming analysis, see: [`https://osf.io/gvm2z/`](https://osf.io/gvm2z/)
#
# ## This is a bit of a playground for the data, as an adjunct to the 'real' analysis going on in redcard_notebook
#
#
# #### In particular it would be cool to use D3 and mplD3 (`install with pip install mpld3`) to visualise the data in interesting ways

# %%
# - - - - - - IMPORT LIBRARIES   
# %matplotlib inline
print "importing libraries"
import pandas as pd #for dealing with csv import
import numpy as np #arrays and other matlab like manipulation
import os # for joining paths and filenames sensibly
import matplotlib.pyplot as plt  # Matplotlib's pyplot: MATLAB-like syntax
import scipy.stats.mstats as ssm #for bootstrap
import random
import mpld3

mpld3.enable_notebook()
# Out:
# importing libraries

# %%
# - - - - - - GET THE DATA

print "loading datafiles"
filename=os.path.join('data','crowdstorm_dataset.csv') 
df = pd.read_csv(filename)
# Out:
# loading datafiles

# %%
# Example data for one player
df.iloc[0,:]
# Out:
# /Library/Python/2.7/site-packages/pandas-0.13.1_213_gc174c3d-py2.7-macosx-10.9-intel.egg/pandas/core/common.py:275: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return -res
# playerShort             lucas-wilchez
# player                  Lucas Wilchez
# club                    Real Zaragoza
# leagueCountry                   Spain
# birthday                   31.08.1983
# height                            177
# weight                             72
# position         Attacking Midfielder
# games                               1
# victories                           0
# ties                                0
# defeats                             1
# goals                               0
# yellowCards                         0
# yellowReds                          0
# redCards                            0
# photoID                     95212.jpg
# ...

# %%
# All data from a single column (birthdays)
df.iloc[:,4]
# Out:
# /Library/Python/2.7/site-packages/pandas-0.13.1_213_gc174c3d-py2.7-macosx-10.9-intel.egg/pandas/core/common.py:275: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return -res
# /Library/Python/2.7/site-packages/pandas-0.13.1_213_gc174c3d-py2.7-macosx-10.9-intel.egg/pandas/core/common.py:275: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return -res
# 0     31.08.1983
# 1     08.01.1982
# 2     17.12.1992
# 3     31.08.1993
# 4     18.07.1991
# 5     08.11.1979
# 6     10.11.1985
# 7     04.04.1986
# 8     13.04.1984
# 9     13.03.1987
# 10    26.01.1984
# 11    05.07.1986
# 12    29.02.1988
# 13    25.02.1982
# 14    14.12.1984
# ...
# 146013    21.06.1987
# 146014    24.01.1983
# 146015    25.10.1981
# 146016    20.04.1976
# 146017    12.10.1981
# ...

# %%
height = df.iloc[:,5].tolist()
birthday = df.iloc[:,4].tolist()
#birthday?
birthyear = [i.rsplit('.', 1)[1] for i in birthday]

birthyear?

# %%
#Take the first 1000 and plot (plotting everything breaks my machine)

h = height[0:1000]
b = birthyear[0:1000]
#h?

# %%
from mpld3 import plugins
ig, ax = plt.subplots(subplot_kw=dict(axisbg='#EEEEEE'))
ax.grid(color='white', linestyle='solid')

scatter = ax.scatter(b,h)

ax.set_title("Are younger players taller?", size=18);

#Next bit doesn't work yet
labels = [df['player']]
fig.plugins = [plugins.PointLabelTooltip(scatter, labels)]

# %%
# Example mpld3 code from http://jakevdp.github.io/blog/2014/01/10/d3-plugins-truly-interactive/
from mpld3 import plugins

fig, ax = plt.subplots(subplot_kw=dict(axisbg='#EEEEEE'))
ax.grid(color='white', linestyle='solid')

N = 50
scatter = ax.scatter(np.random.normal(size=N),
                     np.random.normal(size=N),
                     c=np.random.random(size=N),
                     s = 1000 * np.random.random(size=N),
                     alpha=0.3,
                     cmap=plt.cm.jet)

ax.set_title("D3 Scatter Plot (with tooltips!)", size=20)

labels = ['point {0}'.format(i + 1) for i in range(N)]
fig.plugins = [plugins.PointLabelTooltip(scatter, labels)]

# %%
# Out:
# Average dyad skintone = 2.134

# %%
# Out:
# overserved skintone bias = +0.085

# %%
# Out:
# Starting bootstrap calculations
# iteration 0 of 20
# iteration 1 of 20
# iteration 2 of 20
# iteration 3 of 20
# iteration 4 of 20
# iteration 5 of 20
# iteration 6 of 20
# iteration 7 of 20
# iteration 8 of 20
# iteration 9 of 20
# iteration 10 of 20
# iteration 11 of 20
# iteration 12 of 20
# iteration 13 of 20
# iteration 14 of 20
# iteration 15 of 20
# iteration 16 of 20
# iteration 17 of 20
# iteration 18 of 20
# iteration 19 of 20
# 0.0577136975319
# -0.0463301794747

# %%
# - - - - - - ODDS AND ENDS, EXAMPLE CODE, ETC
#EXAMPLE: let's look at a single row (ie one player-ref interaction
df.iloc[4]

#EXAMPLE: take a single column of the data file
# nb this is nonsense for a variable like height because each player contributes multple entries (1 per interaction)

#Don't do this for proper analysis, since variable ordering is implicit
#...and probably screwed up by dropping nan values

#tolist() converts from series to list
#dropna() drops nans


#height=df['height'].dropna().tolist()
#
#print "plotting"
#
#plt.clf()
#plt.hist(height,20)
#
#print "saving plots"
#plt.title('Height histogram for '+ str(len(height))+ ' dyads')
#plt.xlabel('Height in cm')
#plt.ylabel('frequency')
#plt.savefig('figs/height_hist.png', dpi=300, facecolor='w', edgecolor='w',
#            orientation='portrait', papertype=None, format=None,
#            transparent=False, bbox_inches=None, pad_inches=0.1)
#      


#liverpool players
TheReds=df[df.club == 'Liverpool FC']

#number of red cards in that player-ref dyad
rcards=TheReds['redCards'].tolist()

#name of player in that player-red dyad
names=TheReds['player'].tolist()

#print all player names who have had a red card
for i in range(0,len(names)):
    if rcards[i]>0:
        print names[i]


#            
#"""
#TODO
#
#Calculate an aggregate "red cardness" variable from yellowReds and redCards variables (and yellowCard?)
#Calculate an estimate skin colour variabel from rater1 and rater2 variables
#
#Are these two related?
#"""
# Out:
#  Pepe Reina
# Steven Gerrard
# Jack Robinson
# Brad Jones
#  Doni
# Martin Škrtel
# Steven Gerrard
# Luis Suárez
# Jamie Carragher
# Jordan Henderson
# Jonjo Shelvey
# Joe Cole
#  Pepe Reina
#  Lucas Leiva
# Jamie Carragher
# Jamie Carragher
# Steven Gerrard
# Luis Suárez
#  Doni
# Jack Robinson
# Daniel Agger
#  Lucas Leiva
# Brad Jones
# Andre Wisdom

# %% [markdown]
# If certain players play more often (almost certainly true) they will contribute more weight to any dyad-based statistics
